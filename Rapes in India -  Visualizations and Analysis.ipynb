# %% [markdown]
# # Aiman Alam
# # Instructor - prof. Jan Lorenz
# # Data Visualizations and Data Story Telling
# # Rapes in India - Visualizations and Anaylsis

# %% [markdown]
# ## Importing Libraries

# %%
#Importing important libraries used for upcoming anaylsis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Accessing Dataset
#
# ## Victims of Rape - 2016 to 2021

# %%
# Read the datasets

D16 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\Victims of Rape - 2016.xlsx")
D17 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\Victims of Rape - 2017.xls")
D18 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\Victims of Rapes - 2018.xlsx")
D19 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\Victims of Rape - 2019.xlsx")
D20 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\Victims of Rape - 2020.xlsx")
D21 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\Victims of Rapes - 2021.xlsx")

# %% [markdown]
# ## Analysis of Year - 2016

# %%
D16.head()
# Out:
#             State/UT  Cases Reported  Victims below 6 years - Girls  \
# 0     Andhra Pradesh             994                             17
# 1  Arunachal Pradesh              92                              3
# 2              Assam            1779                              0
# 3              Bihar            1008                              0
# 4       Chhattisgarh            1626                             33
#
#    Victims 6 - 12 years - Girls  Victims 12 - 16 Years - Girls  \
# 0                            43                            142
# 1                            12                             25
# 2                            52                            147
# 3                             7                             41
# 4                            79                            340
#
#    Victims 16 - 18 years - Girls  Total Victims - Girls  \
# 0                            261                    463
# 1                             10                     50
# 2                            265                    464
# 3                            121                    169
# 4                            532                    984
#
#    Victims 18 - 30 years - Women  Victims 30 - 45 years - Women  \
# 0                            436                             85
# 1                             32                              7
# 2                            938                            373
# 3                            684                            146
# 4                            475                            150
#
#    Victims 45 - 60 years - Women  Victims above 60 years - Women  \
# 0                              9                               2
# 1                              2                               1
# 2                              4                               0
# 3                              9                               0
# 4                             13                               5
#
#    Total Victims - Women  Total Victims
# 0                    532            995
# 1                     42             92
# 2                   1315           1779
# 3                    839           1008
# 4                    643           1627

# %%
#lets visualize the above state list

# D18 is the DataFrame with 'State/UT' and 'Total Victims' columns

fig = px.bar(D16, y='State/UT', x='Total Victims', title='Total Victims in State/UT for Year - 2016',
             labels={'Total Victims': 'Total Victims Count', 'State/UT': 'State/UT'})

# Increase the size of the graph
fig.update_layout(height=800, width=1000)

# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="6df8aedc-aa55-4ffb-a253-8aeb938cca06" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6df8aedc-aa55-4ffb-a253-8aeb938cca06")) {                    Plotly.newPlot(                        "6df8aedc-aa55-4ffb-a253-8aeb938cca06",                        [{"alignmentgroup":"True","hovertemplate":"Total Victims Count=%{x}<br>State/UT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[995,92,1779,1008,1627,61,986,1189,258,256,1110,1671,1661,4908,4216,55,194,23,26,1984,840,3657,98,320,1278,207,4817,336,1110,30,69,14,12,2170,5,6],"xaxis":"x","y":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D&N Haveli","Daman & Diu","Delhi","Lakshadweep","Puducherry"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":1 ...

# %% [markdown]
# ### Most targeted age group of rape - 2016

# %%
# Create a new dataset for percentages
percentage_data = D16.copy()

# Calculate percentages for each age group
age_groups = ['Victims below 6 years - Girls', 'Victims 6 - 12 years - Girls', 'Victims 12 - 16 Years - Girls',
              'Victims 16 - 18 years - Girls', 'Victims 18 - 30 years - Women', 'Victims 30 - 45 years - Women',
              'Victims 45 - 60 years - Women', 'Victims above 60 years - Women']

for age_group in age_groups:
    percentage_data[age_group] = ((D16[age_group] / D16['Total Victims']) * 100).round(2)

# Drop unnecessary columns (if needed)
percentage_data = percentage_data.drop(columns=['Total Victims - Girls', 'Total Victims - Women', 'Total Victims'])

# Display the resulting dataset
percentage_data.head()
# Out:
#             State/UT  Cases Reported  Victims below 6 years - Girls  \
# 0     Andhra Pradesh             994                              2
# 1  Arunachal Pradesh              92                              3
# 2              Assam            1779                              0
# 3              Bihar            1008                              0
# 4       Chhattisgarh            1626                              2
#
#    Victims 6 - 12 years - Girls  Victims 12 - 16 Years - Girls  \
# 0                             4                             14
# 1                            13                             27
# 2                             3                              8
# 3                             1                              4
# 4                             5                             21
#
#    Victims 16 - 18 years - Girls  Victims 18 - 30 years - Women  \
# 0                             26                             44
# 1                             11                             35
# 2                             15                             53
# 3                             12                             68
# 4                             33                             29
#
#    Victims 30 - 45 years - Women  Victims 45 - 60 years - Women  \
# 0                              9                              1
# 1                              8                              2
# 2                             21                              0
# 3                             14                              1
# 4                              9                              1
#
#    Victims above 60 years - Women
# 0                               0
# 1                               1
# 2                               0
# 3                               0
# 4                               0

# %%
# lets see which age group have highest victims via heatmap

# for that we need to remove the total count columns from dataset 
#because obviously they will have max value and will be marked highest in the heat map

columns_to_drop = ['Cases Reported']

# new DataFrame with specified columns dropped

percentage_data = percentage_data.drop(columns=columns_to_drop)

# %%
# Set the state column as the index for better visualization
percentage_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(percentage_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Victims by Age Group and State - 2016')
plt.show()

# %% [markdown]
# ## Analysis of Year - 2017

# %%
D17.head()
# Out:
#             State/UT  Cases Reported   Victims Below 6 years- Girls  \
# 0     Andhra Pradesh              988                            17
# 1  Arunachal Pradesh               59                             1
# 2              Assam             1772                             9
# 3              Bihar              605                             2
# 4       Chhattisgarh             1908                            96
#
#    Victims 6- 12 years - Girls  Victims 12 to 16 years - Girls  \
# 0                           68                             248
# 1                           15                              23
# 2                          201                             337
# 3                           44                             126
# 4                          166                             809
#
#    Victims 16 to 18 years - Girls  Total Victims - Girls  \
# 0                             417                    750
# 1                              14                     53
# 2                             351                    898
# 3                             427                    599
# 4                            1166                   2237
#
#    Victims 18 - 30 years- women  Victims 30 - 45 years - women  \
# 0                           333                            121
# 1                            24                              5
# 2                          1291                            582
# 3                           546                             68
# 4                           525                            245
#
#    Victims 45 - 60 Years - Women  Victims above 60 years - Women  \
# 0                              6                               4
# 1                              0                               0
# 2                             75                               0
# 3                              2                               0
# 4                             14                               8
#
#    Total Victims - Women  Total Victims
# 0                    464           1214
# 1                     29             82
# 2                   1948           2846
# 3                    616           1215
# 4                    792           3029

# %%
# D17 is the DataFrame with 'State/UT' and 'Total Victims' columns

fig = px.bar(D17, y='State/UT', x='Total Victims', title='Highest and lowest Total Victims in State/UT for Year - 2017',
             labels={'Total Victims': 'Total Victims Count', 'State/UT': 'State/UT'})
# Increase the size of the graph
fig.update_layout(height=800, width=1000)
# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="e76331c4-79f3-4e06-a7c1-ef2924fa0386" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e76331c4-79f3-4e06-a7c1-ef2924fa0386")) {                    Plotly.newPlot(                        "e76331c4-79f3-4e06-a7c1-ef2924fa0386",                        [{"alignmentgroup":"True","hovertemplate":"Total Victims Count=%{x}<br>State/UT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1214,82,2846,1215,3029,76,1716,1724,253,298,1180,1911,2247,6549,4341,55,286,155,38,2232,925,3939,86,1431,1722,207,6261,578,2294,60,65,7,10,2172,3,48],"xaxis":"x","y":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D&N Haveli","Daman & Diu","Delhi","Lakshadweep","Puducherry"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","siz ...

# %% [markdown]
# ### Geogriphical Heat Map for Total victims of Rape - 2017

# %%
import plotly.graph_objects as go



fig = go.Figure(go.Choroplethmapbox(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locations=D17['State/UT'],
    z=D17['Total Victims'],
    colorscale='Reds',
    colorbar=dict(thickness=15, ticklen=3),
))

fig.update_layout(
    mapbox=dict(
        center=dict(lat=20, lon=77),
        style="carto-positron",
        zoom=3,
    ),
    margin=dict(l=0, r=0, t=0, b=0),
)

fig.show()
# Out:
# <div>                            <div id="fb8184fe-6c56-4907-bd7e-d738ba9d7b76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb8184fe-6c56-4907-bd7e-d738ba9d7b76")) {                    Plotly.newPlot(                        "fb8184fe-6c56-4907-bd7e-d738ba9d7b76",                        [{"colorbar":{"thickness":15,"ticklen":3},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"featureidkey":"properties.ST_NM","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","locations":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D&N Haveli","Daman & Diu","Delhi","Lakshadweep","Puducherry"],"z":[1214,82,2846,1215,3029,76,1716,1724,253,298,1180,1911,2247,6549,4341,55,286,155,38,2232,925,3939,86,1431,1722,207,6261,578,2294,60,65,7,10,2172,3,48],"type":"choroplethmapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7 ...

# %% [markdown]
# ### Data for Rate of Rape - 2017 - Calculated using population data from Aadhaar card registrations

# %%
P17 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population 2017.xlsx")
P17.head(3)
# Out:
#             State/UT  Population
# 0     Andhra Pradesh    52375124
# 1  Arunachal Pradesh     1506749
# 2              Assam    34068394

# %%
# Set the display format for float values
pd.options.display.float_format = '{:.0f}'.format

P17['Female Population'] = 0.48 * P17['Population']


# Display the resulting dataset
P17.head(3)
# Out:
#             State/UT  Population  Female Population
# 0     Andhra Pradesh    52375124           25140060
# 1  Arunachal Pradesh     1506749             723240
# 2              Assam    34068394           16352829

# %%
# Drop the 'Population' column from 'P17'
P17 = P17.drop(columns=['Population'])

# Merge 'Total Victims' column from 'D17' to 'P17'
P17 = pd.merge(P17, D17[['State/UT', 'Total Victims']], on='State/UT', how='left')

# %%
# Create a new column 'Victims per Million'
P17['Victims per Million'] = (P17['Total Victims'] / P17['Female Population']) * 1000000
P17.head(3)
# Out:
#             State/UT  Female Population  Total Victims  Victims per Million
# 0     Andhra Pradesh           25140060           1214                   48
# 1  Arunachal Pradesh             723240             82                  113
# 2              Assam           16352829           2846                  174

# %%
# Create a new dataset with relevant columns
heatmap_data = P17[['State/UT', 'Victims per Million']]

# Set the 'State/UT' column as the index for the heatmap data
heatmap_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Cases vs. Population by State')
plt.show()

# %%
# Sort the dataset based on 'Victims per Million' column in descending order
P17_sorted = P17.sort_values(by='Victims per Million', ascending=False)
P17_sorted.head(3)
# Out:
#          State/UT  Female Population  Total Victims  Victims per Million
# 29  A & N Islands             198747             60                  302
# 17        Mizoram             570706            155                  272
# 22         Sikkim             317880             86                  271

# %%
# Select the top 10 states
top_10_states = P17_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Victims per Million', y='State/UT', data=top_10_states, palette='viridis')
plt.title('Top 10 States with Highest Victims per Million')
plt.xlabel('Victims per Million')
plt.ylabel('State/UT')
plt.show()

# %% [markdown]
# ### Most targeted age group - 2017

# %%
# Create a new dataset for percentages
percentage_data = D17.copy()

# Calculate percentages for each age group
age_groups = ['Victims Below 6 years- Girls', 'Victims 6- 12 years - Girls', 'Victims 12 to 16 years - Girls',
              'Victims 16 to 18 years - Girls', 'Total Victims - Girls', 'Victims 18 - 30 years- women',
              'Victims 30 - 45 years - women', 'Victims 45 - 60 Years - Women', 'Victims above 60 years - Women']

for age_group in age_groups:
    percentage_data[age_group] = ((D17[age_group] / D17['Total Victims']) * 100).round(2)

# Drop unnecessary columns (if needed)
percentage_data = percentage_data.drop(columns=['Total Victims - Girls', 'Total Victims - Women', 'Total Victims'])

# Display the resulting dataset
percentage_data.head(2)
# Out:
#             State/UT  Cases Reported   Victims Below 6 years- Girls  \
# 0     Andhra Pradesh              988                             1
# 1  Arunachal Pradesh               59                             1
#
#    Victims 6- 12 years - Girls  Victims 12 to 16 years - Girls  \
# 0                            6                              20
# 1                           18                              28
#
#    Victims 16 to 18 years - Girls  Victims 18 - 30 years- women  \
# 0                              34                            27
# 1                              17                            29
#
#    Victims 30 - 45 years - women  Victims 45 - 60 Years - Women  \
# 0                             10                              0
# 1                              6                              0
#
#    Victims above 60 years - Women
# 0                               0
# 1                               0

# %%
# lets see which age group have highest victims via heatmap

# for that we need to remove the total count columns from dataset 
#because obviously they will have max value and will be marked highest in the heat map

columns_to_drop = ['Cases Reported ']

# new DataFrame with specified columns dropped

percentage_data = percentage_data.drop(columns=columns_to_drop)

# %%
# Set the state column as the index for better visualization
percentage_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(percentage_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Victims by Age Group and State for 2017')
plt.show()

# %% [markdown]
# ## Analysis of Year - 2018

# %%
D18.head()
# Out:
#             State/UT  Victims Below 6 Years - Girls  \
# 0     Andhra Pradesh                             28
# 1  Arunachal Pradesh                              5
# 2              Assam                             44
# 3              Bihar                              4
# 4       Chhattisgarh                             81
#
#    Victims 6 to 12 years- Girls  Victims 12 - 16 years - Girls  \
# 0                            85                            289
# 1                            10                             22
# 2                           278                            471
# 3                            67                            396
# 4                           166                           1138
#
#    Victims 16 - 18 years - Girls  Total Victims - Girls  \
# 0                            348                    750
# 1                             13                     50
# 2                            529                   1322
# 3                            407                    874
# 4                           1056                   2441
#
#    Victims 18 - 30 years - Women  Victims 30 - 45  years - Women  \
# 0                            373                              76
# 1                             29                               9
# 2                           1043                             523
# 3                            520                             111
# 4                            644                             190
#
#    Victims 45 - 60  years - Women  Victims above 60  years - Women  \
# 0                              14                                5
# 1                               0                                0
# 2                             107                                5
# 3                              16                                0
# 4                              42                                6
#
#    Total Victims - Women  Total Victims
# 0                    468           1218
# 1                     38             88
# 2                   1678           3000
# 3                    647           1521
# 4                    882           3323

# %%
D18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State/UT                         36 non-null     object
#  1   Victims Below 6 Years - Girls    36 non-null     int64
#  2   Victims 6 to 12 years- Girls     36 non-null     int64
#  3   Victims 12 - 16 years - Girls    36 non-null     int64
#  4   Victims 16 - 18 years - Girls    36 non-null     int64
#  5   Total Victims - Girls            36 non-null     int64
#  6   Victims 18 - 30 years - Women    36 non-null     int64
#  7   Victims 30 - 45  years - Women   36 non-null     int64
#  8   Victims 45 - 60  years - Women   36 non-null     int64
#  9   Victims above 60  years - Women  36 non-null     int64
#  10  Total Victims - Women            36 non-null     int64
#  11  Total Victims                    36 non-null     int64
# dtypes: int64(11), object(1)
# memory usage: 3.5+ KB

# %%
# Create the bar chart
fig = px.bar(D18, y='State/UT', x='Total Victims', title='Highest to lowest Total Victims in State/UT for Year - 2018',
             labels={'Total Victims': 'Total Victims Count', 'State/UT': 'State/UT'})

# Increase the size of the graph
fig.update_layout(height=800, width=1000)

# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="b276fff1-9dcc-47de-a043-7c94f1609aff" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b276fff1-9dcc-47de-a043-7c94f1609aff")) {                    Plotly.newPlot(                        "b276fff1-9dcc-47de-a043-7c94f1609aff",                        [{"alignmentgroup":"True","hovertemplate":"Total Victims Count=%{x}<br>State/UT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1218,88,3000,1521,3323,61,2043,2317,371,350,1547,1916,2096,6498,5093,85,267,122,19,2354,1125,4412,95,1781,1748,173,6447,866,2438,81,86,25,3,2206,3,47],"xaxis":"x","y":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D&N Haveli","Daman & Diu","Delhi","Lakshadweep","Puducherry"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","si ...

# %% [markdown]
# ### Geogriphical Heat Map for Total victims of Rape - 2018

# %%
import plotly.graph_objects as go


fig = go.Figure(go.Choroplethmapbox(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locations=D18['State/UT'],
    z=D18['Total Victims'],
    colorscale='Reds',
    colorbar=dict(thickness=15, ticklen=3),
))

fig.update_layout(
    mapbox=dict(
        center=dict(lat=20, lon=77),
        style="carto-positron",
        zoom=3,
    ),
    margin=dict(l=0, r=0, t=0, b=0),
)

fig.show()
# Out:
# <div>                            <div id="154fb743-a1ba-4fdc-83ff-b498dcb13dee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("154fb743-a1ba-4fdc-83ff-b498dcb13dee")) {                    Plotly.newPlot(                        "154fb743-a1ba-4fdc-83ff-b498dcb13dee",                        [{"colorbar":{"thickness":15,"ticklen":3},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"featureidkey":"properties.ST_NM","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","locations":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D&N Haveli","Daman & Diu","Delhi","Lakshadweep","Puducherry"],"z":[1218,88,3000,1521,3323,61,2043,2317,371,350,1547,1916,2096,6498,5093,85,267,122,19,2354,1125,4412,95,1781,1748,173,6447,866,2438,81,86,25,3,2206,3,47],"type":"choroplethmapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed ...

# %% [markdown]
# ### Accessing Population Data - 2018

# %%
P18 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population 2018.xlsx")
P18.head(2)
# Out:
#    State/UT                 Population
# 0  Andhra Pradesh             52883163
# 1  Arunachal Pradesh           1528296

# %%
# Remove any leading or trailing spaces in column names
P18.columns = P18.columns.str.strip()

# Set the display format for float values
pd.options.display.float_format = '{:.0f}'.format

# Assuming 'Population' is the correct column name
P18['Female Population'] = 0.48 * P18['Population']

# Display the resulting dataset
P18.head(3)
# Out:
#                  State/UT  Population  Female Population
# 0  Andhra Pradesh            52883163           25383918
# 1  Arunachal Pradesh          1528296             733582
# 2  Assam                     34586234           16601392

# %%
# Clean the 'State/UT' column in both DataFrames
P18['State/UT'] = P18['State/UT'].str.strip()
D18['State/UT'] = D18['State/UT'].str.strip()

# Drop the 'Population' column from 'P17'
P18 = P18.drop(columns=['Population'])

# Merge 'Total Victims' column from 'D17' to 'P17'
P18 = pd.merge(P18, D18[['State/UT', 'Total Victims']], on='State/UT', how='left')

# %%
# Create a new column 'Victims per Million'
P18['Victims per Million'] = (P18['Total Victims'] / P18['Female Population']) * 1000000
P18.head(3)
# Out:
#             State/UT  Female Population  Total Victims  Victims per Million
# 0     Andhra Pradesh           25383918           1218                   48
# 1  Arunachal Pradesh             733582             88                  120
# 2              Assam           16601392           3000                  181

# %%
# Create a new dataset with relevant columns
heatmap_data = P18[['State/UT', 'Victims per Million']]

# Set the 'State/UT' column as the index for the heatmap data
heatmap_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Cases vs. Population by State')
plt.show()

# %% [markdown]
# ### Geogriphical Heat Map for Rate of Rape - 2018

# %%
import plotly.graph_objects as go


fig = go.Figure(go.Choroplethmapbox(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locations=P18['State/UT'],
    z=P18['Victims per Million'],
    colorscale='Reds',
    colorbar=dict(thickness=15, ticklen=3),
))

fig.update_layout(
    mapbox=dict(
        center=dict(lat=20, lon=77),
        style="carto-positron",
        zoom=3,
    ),
    margin=dict(l=0, r=0, t=0, b=0),
)

fig.show()
# Out:
# <div>                            <div id="040bebae-f9f7-4c4b-8a77-c4cfe0903a8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("040bebae-f9f7-4c4b-8a77-c4cfe0903a8e")) {                    Plotly.newPlot(                        "040bebae-f9f7-4c4b-8a77-c4cfe0903a8e",                        [{"colorbar":{"thickness":15,"ticklen":3},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"featureidkey":"properties.ST_NM","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","locations":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D&N Haveli","Daman & Diu","Delhi","Lakshadweep","Puducherry"],"z":[47.983135955767246,119.95930980211513,180.70773475944216,26.525390338017647,242.33973081051474,82.37454761518933,66.60047694156526,176.2480620472045,105.6372164457932,53.47753075844218,86.33785034214213,60.328167700598264,123.59345926053902,164.40418774718998,87.80742816760673,58.860104958785186,169.7787428162608,210.75634024171885,18.080385316991403,107.95138774930011,79.14882968640855,117.49419393333014,294.641616546577,48.51388222696948,94.65569443849147,88.81967867853734,58.66209610194155,162.67786551612463,51.99005830665847,401.8067613065446,159.01825825452684,137.430657987206,28.398247941694994,250.51168886177516,87.75871268499536,71.18147435189117],"type":"choroplethmapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...

# %%
# Sort the dataset based on 'Victims per Million' column in descending order
P18_sorted = P18.sort_values(by='Victims per Million', ascending=False)
P18_sorted.head(2)
# Out:
#          State/UT  Female Population  Total Victims  Victims per Million
# 29  A & N Islands             201589             81                  402
# 22         Sikkim             322426             95                  295

# %%
# Select the top 10 states
top_10_states = P18_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Victims per Million', y='State/UT', data=top_10_states, palette='viridis')
plt.title('Top 10 States with Highest Victims per Million')
plt.xlabel('Victims per Million')
plt.ylabel('State/UT')
plt.show()

# %% [markdown]
# ### Most targeted age group - 2018

# %%
# Create a new dataset for percentages
percentage_data = D18.copy()

# Correct column names with spaces
age_groups = ['Victims Below 6 Years - Girls', 'Victims 6 to 12 years- Girls', 'Victims 12 - 16 years - Girls',
              'Victims 16 - 18 years - Girls', 'Total Victims - Girls', 'Victims 18 - 30 years - Women',
              'Victims 30 - 45  years - Women', 'Victims 45 - 60  years - Women', 'Victims above 60  years - Women']

# Loop to calculate percentages for each age group
for age_group in age_groups:
    percentage_data[age_group] = ((D18[age_group] / D18['Total Victims']) * 100).round(2)

# Drop unnecessary columns (if needed)
percentage_data = percentage_data.drop(columns=['Total Victims - Girls', 'Total Victims - Women', 'Total Victims'])

# Display the resulting dataset
percentage_data.head(2)
# Out:
#             State/UT  Victims Below 6 Years - Girls  \
# 0     Andhra Pradesh                              2
# 1  Arunachal Pradesh                              6
#
#    Victims 6 to 12 years- Girls  Victims 12 - 16 years - Girls  \
# 0                             7                             24
# 1                            11                             25
#
#    Victims 16 - 18 years - Girls  Victims 18 - 30 years - Women  \
# 0                             29                             31
# 1                             15                             33
#
#    Victims 30 - 45  years - Women  Victims 45 - 60  years - Women  \
# 0                               6                               1
# 1                              10                               0
#
#    Victims above 60  years - Women
# 0                                0
# 1                                0

# %%
# Set the state column as the index for better visualization
percentage_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(percentage_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Victims by Age Group and State')
plt.show()

# %% [markdown]
# ## Analysis of Year - 2019

# %%
D19.head(2)
# Out:
#             State/UT  Victims - below 6 years - Girls  \
# 0     Andhra Pradesh                               30
# 1  Arunachal Pradesh                                1
#
#    Victims -  6- 12  years - Girls  Victims -  12 - 16  years - Girls  \
# 0                               65                                262
# 1                                6                                 23
#
#    Victims - 16 - 18 years - Girls  Total Victims Girls  \
# 0                              470                  827
# 1                               19                   49
#
#    Victims 18 - 30 Years - Women  Victims 30 - 45 Years - Women  \
# 0                            431                             89
# 1                             26                             12
#
#    Victims 45 - 60  Years - Women  Victims above 60 Years - Women  \
# 0                              21                               2
# 1                               1                               0
#
#    Total Victims - Women  Total Victims
# 0                    543           1370
# 1                     39             88

# %%
# Create the bar chart
fig = px.bar(D19, y='State/UT', x='Total Victims', title='Highest to lowest Total Victims in State/UT for Year - 2019',
             labels={'Total Victims': 'Total Victims Count', 'State/UT': 'State/UT'})

# Increase the size of the graph
fig.update_layout(height=800, width=1000)

# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="4cfc4f01-1f91-4835-abc0-6678bb40bc45" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cfc4f01-1f91-4835-abc0-6678bb40bc45")) {                    Plotly.newPlot(                        "4cfc4f01-1f91-4835-abc0-6678bb40bc45",                        [{"alignmentgroup":"True","hovertemplate":"Total Victims Count=%{x}<br>State/UT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1370,88,3081,1460,2427,74,2076,2599,361,298,1887,2149,2111,5839,5466,83,247,79,20,2888,1243,6053,69,2091,2064,197,6432,757,2438,96,113,38,13,2210,14,58],"xaxis":"x","y":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D & N Haveli","Daman & Diu","Delhi","Lakshadweep","Puducherry"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay" ...

# %% [markdown]
# ### Accessing Population Data - 2019

# %%
P19 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population 2019.xlsx")
P19.head(2)
# Out:
#     State/UT                                        Population
# 0   Andhra Pradesh                                        53390841
# 1   Arunachal Pradesh                                      1548776

# %%
# Remove any leading or trailing spaces in column names
P19.columns = P19.columns.str.strip()

# Set the display format for float values
pd.options.display.float_format = '{:.0f}'.format

# Assuming 'Population' is the correct column name
P19['Female Population'] = 0.48 * P19['Population']

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> FROM 2019, THE TWO SEPARATE STATES - 'DAMAN AND DIU' AND 'D AND N HVELI' WERE MERGED. THEREFORE THEIR VICTIMS WERE ADDED AND STORED IN A FEW EXCEL FILE, SINCE MERGING WILL NOT WORK </div>

# %%
#accessing the new dataset with the two states merged

PV19 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population vs total victims 2019.xlsx")
PV19
# Out:
#                       State/UT  Female Population  Total Victims
# 0               Andhra Pradesh           25627604           1370
# 1            Arunachal Pradesh             743412             88
# 2                        Assam           16838797           3081
# 3                        Bihar           58683351           1460
# 4                 Chhattisgarh           13915099           2427
# 5                          Goa             750888             74
# 6                      Gujarat           31104912           2076
# 7                      Haryana           13340808           2599
# 8             Himachal Pradesh            3544331            361
# 9              Jammu & Kashmir            6464790            298
# 10                   Jharkhand           18208271           1887
# 11                   Karnataka           32080413           2149
# 12                      Kerala           17021688           2111
# 13              Madhya Pradesh           40247842           5839
# 14                 Maharashtra           58523987           5466
# 15                     Manipur            1463453             83
# 16                   Meghalaya            1593708            247
# 17                     Mizoram             586624             79
# 18                    Nagaland            1064944             20
# 19                      Odisha           22013297           2888
# 20                      Punjab           14340231           1243
# 21                   Rajasthan           38200442           6053
# 22                      Sikkim             326746             69
# 23                  Tamil Nadu           37045219           2091
# 24                   Telangana           18681146           2064
# 25                     Tripura            1973867            197
# 26               Uttar Pradesh          112021689           6432
# 27                 Uttarakhand            5347472            757
# 28                 West Bengal           47357830           2438
# 29               A & N Islands             197413             96
# 30                  Chandigarh             548390            113
# 31  D&N Haveli and Daman & Diu             291467             51
# 32                       Delhi            8879132           2210
# 33                 Lakshadweep              34643             14
# 34                  Puducherry             669132             58

# %%
# Create a new column 'Victims per Million'
PV19['Victims per Million'] = (PV19['Total Victims'] / PV19['Female Population']) * 1000000
PV19.head(3)
# Out:
#             State/UT  Female Population  Total Victims  Victims per Million
# 0     Andhra Pradesh           25627604           1370                   53
# 1  Arunachal Pradesh             743412             88                  118
# 2              Assam           16838797           3081                  183

# %%
# Create a new dataset with relevant columns
heatmap_data = PV19[['State/UT', 'Victims per Million']]

# Set the 'State/UT' column as the index for the heatmap data
heatmap_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Cases vs. Population by State - 2019')
plt.show()

# %%
# Sort the dataset based on 'Victims per Million' column in descending order
PV19_sorted = PV19.sort_values(by='Victims per Million', ascending=False)
PV19_sorted.head(2)
# Out:
#          State/UT  Female Population  Total Victims  Victims per Million
# 29  A & N Islands             197413             96                  486
# 33    Lakshadweep              34643             14                  404

# %%
# Select the top 10 states
top_10_states = PV19_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Victims per Million', y='State/UT', data=top_10_states, palette='viridis')
plt.title('Top 10 States with Highest Victims per Million - 2019')
plt.xlabel('Victims per Million')
plt.ylabel('State/UT')
plt.show()

# %% [markdown]
# ### Most targeted age group - 2019

# %%
# Create a new dataset for percentages
percentage_data = D19.copy()

# Correct column names with spaces
age_groups = ['Victims - below 6 years - Girls', 'Victims -  6- 12  years - Girls', 
              'Victims -  12 - 16  years - Girls', 'Victims - 16 - 18 years - Girls',
              'Total Victims Girls', 'Victims 18 - 30 Years - Women',
              'Victims 30 - 45 Years - Women', 'Victims 45 - 60  Years - Women',
              'Victims above 60 Years - Women']

# Loop to calculate percentages for each age group
for age_group in age_groups:
    percentage_data[age_group] = ((D19[age_group] / D19['Total Victims']) * 100).round(2)

# Drop unnecessary columns (if needed)
percentage_data = percentage_data.drop(columns=['Total Victims Girls', 'Total Victims - Women', 'Total Victims'])

# Display the resulting dataset
percentage_data.head(2)
# Out:
#             State/UT  Victims - below 6 years - Girls  \
# 0     Andhra Pradesh                                2
# 1  Arunachal Pradesh                                1
#
#    Victims -  6- 12  years - Girls  Victims -  12 - 16  years - Girls  \
# 0                                5                                 19
# 1                                7                                 26
#
#    Victims - 16 - 18 years - Girls  Victims 18 - 30 Years - Women  \
# 0                               34                             31
# 1                               22                             30
#
#    Victims 30 - 45 Years - Women  Victims 45 - 60  Years - Women  \
# 0                              6                               2
# 1                             14                               1
#
#    Victims above 60 Years - Women
# 0                               0
# 1                               0

# %%
# Set the state column as the index for better visualization
percentage_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(percentage_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Victims by Age Group and State - 2019')
plt.show()

# %% [markdown]
# ## Analysis of Year - 2020

# %%
D20.head()
# Out:
#             State/UT  Victims below 6 years - Girls  \
# 0     Andhra Pradesh                             30
# 1  Arunachal Pradesh                              1
# 2              Assam                             10
# 3              Bihar                             12
# 4       Chhattisgarh                             34
#
#    Victims 6 - 12 Years - Girls  Victims 12- 16 years - Girls  \
# 0                            93                           262
# 1                             7                            17
# 2                            91                           474
# 3                            59                           288
# 4                            85                           578
#
#    Victims 16 - 18 years - Girls  Total Victims - Girls  \
# 0                            476                    861
# 1                             20                     45
# 2                            521                   1096
# 3                            270                    629
# 4                            857                   1554
#
#    Victims 18 - 30 years - Women  Victims 30 - 45 years - Women  \
# 0                            411                             87
# 1                             20                             14
# 2                           1006                            584
# 3                            631                            156
# 4                            734                            398
#
#    Victims 45 - 60 years - Women  Above 60 years - Women  \
# 0                             20                       2
# 1                              0                       0
# 2                             50                       0
# 3                             18                       0
# 4                             62                       5
#
#    Total Victims - Women   Total Victims
# 0                     520           1381
# 1                      34             79
# 2                    1640           2736
# 3                     805           1434
# 4                    1199           2753

# %%
# Create the bar chart
fig = px.bar(D20, y='State/UT', x='Total Victims', title='Highest to lowest Total Victims in State/UT for Year - 2020',
             labels={'Total Victims': 'Total Victims Count', 'State/UT': 'State/UT'})

# Increase the size of the graph
fig.update_layout(height=800, width=1000)

# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="1edb4450-2703-44e3-ad68-ecd968cdbbbd" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1edb4450-2703-44e3-ad68-ecd968cdbbbd")) {                    Plotly.newPlot(                        "1edb4450-2703-44e3-ad68-ecd968cdbbbd",                        [{"alignmentgroup":"True","hovertemplate":"Total Victims Count=%{x}<br>State/UT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1381,79,2736,1434,2753,61,2367,2407,332,2008,2154,1906,5603,4865,88,318,91,18,2840,1058,5338,85,2617,2194,166,5329,883,2714,106,60,43,1718,399,2,6,52],"xaxis":"x","y":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D & N Haveli and Daman & Diu","Delhi","Jammu & Kashmir","Ladakh","Lakshadweep","Puducherry"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode": ...

# %% [markdown]
# ### Accessing Population Data - 2020

# %%
P20 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population 2020.xlsx")
P20.head(3)
# Out:
#              State/UT  Population
# 0     Andhra Pradesh     53903393
# 1  Arunachal Pradesh      1570458
# 2              Assam     35607039

# %%
# Remove any leading or trailing spaces in column names
P20.columns = P20.columns.str.strip()

# Set the display format for float values
pd.options.display.float_format = '{:.0f}'.format

# Assuming 'Population' is the correct column name
P20['Female Population'] = 0.48 * P20['Population']

# Display the resulting dataset
P20.head(3)
# Out:
#              State/UT  Population  Female Population
# 0     Andhra Pradesh     53903393           25873629
# 1  Arunachal Pradesh      1570458             753820
# 2              Assam     35607039           17091379

# %%
# Clean the 'State/UT' column in both DataFrames
P20['State/UT'] = P20['State/UT'].str.strip()
D20['State/UT'] = D20['State/UT'].str.strip()

# Drop the 'Population' column from 'P17'
P20 = P20.drop(columns=['Population'])

# Merge 'Total Victims' column from 'D17' to 'P17'
P20 = pd.merge(P20, D20[['State/UT', 'Total Victims']], on='State/UT', how='left')
P20.head(2)
# Out:
#             State/UT  Female Population  Total Victims
# 0     Andhra Pradesh           25873629           1381
# 1  Arunachal Pradesh             753820             79

# %%
#accessing data after merging victims for the two states mentioned above in note

PV20 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population vs total victims 2020.xlsx")
PV20.head(2)
# Out:
#                     State/UT  Female Population  Total Victims
# 0  Andhra Pradesh                      25873629           1381
# 1  Arunachal Pradesh                     753820             79

# %%
# Create a new column 'Victims per Million'
PV20['Victims per Million'] = (PV20['Total Victims'] / PV20['Female Population']) * 1000000
PV20.head(2)
# Out:
#                     State/UT  Female Population  Total Victims  \
# 0  Andhra Pradesh                      25873629           1381
# 1  Arunachal Pradesh                     753820             79
#
#    Victims per Million
# 0                   53
# 1                  105

# %%
# Create a new dataset with relevant columns
heatmap_data = PV20[['State/UT', 'Victims per Million']]

# Set the 'State/UT' column as the index for the heatmap data
heatmap_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Cases vs. Population by State - 2020')
plt.show()

# %%
# Sort the dataset based on 'Victims per Million' column in descending order
PV20_sorted = PV20.sort_values(by='Victims per Million', ascending=False)
PV20_sorted.head(3)
# Out:
#                      State/UT  Female Population  Total Victims  \
# 28  A & N Islands                         200177            106
# 21  Sikkim                                331320             85
# 15  Meghalaya                            1616021            318
#
#     Victims per Million
# 28                  530
# 21                  257
# 15                  197

# %%
# Select the top 10 states
top_10_states = PV20_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Victims per Million', y='State/UT', data=top_10_states, palette='viridis')
plt.title('Top 10 States with Highest Victims per Million - 2020')
plt.xlabel('Victims per Million')
plt.ylabel('State/UT')
plt.show()

# %% [markdown]
# ### Most targeted age group - 2020

# %%
# Create a new dataset for percentages
percentage_data = D20.copy()

# Correct column names with spaces
age_groups = ['Victims below 6 years - Girls', 'Victims 6 - 12 Years - Girls', 'Victims 12- 16 years - Girls',
              'Victims 16 - 18 years - Girls', 'Total Victims - Girls', 'Victims 18 - 30 years - Women',
              'Victims 30 - 45 years - Women', 'Victims 45 - 60 years - Women', 'Above 60 years - Women',
              'Total Victims - Women ', 'Total Victims']

# Check if columns exist before performing operations
for age_group in age_groups:
    if age_group in D20.columns and 'Total Victims' in D20.columns:
        percentage_data[age_group] = ((D20[age_group] / D20['Total Victims']) * 100).round(2)

# Drop unnecessary columns (if needed)
# Note: Adjust the column names based on your dataset
columns_to_drop = ['Total Victims - Girls', 'Total Victims - Women ', 'Total Victims']
percentage_data = percentage_data.drop(columns=columns_to_drop, errors='ignore')

# Display the resulting dataset
percentage_data.head(3)
# Out:
#             State/UT  Victims below 6 years - Girls  \
# 0     Andhra Pradesh                              2
# 1  Arunachal Pradesh                              1
# 2              Assam                              0
#
#    Victims 6 - 12 Years - Girls  Victims 12- 16 years - Girls  \
# 0                             7                            19
# 1                             9                            22
# 2                             3                            17
#
#    Victims 16 - 18 years - Girls  Victims 18 - 30 years - Women  \
# 0                             34                             30
# 1                             25                             25
# 2                             19                             37
#
#    Victims 30 - 45 years - Women  Victims 45 - 60 years - Women  \
# 0                              6                              1
# 1                             18                              0
# 2                             21                              2
#
#    Above 60 years - Women
# 0                       0
# 1                       0
# 2                       0

# %%
# Set the state column as the index for better visualization
percentage_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(percentage_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Victims by Age Group and State - 2020')
plt.show()

# %% [markdown]
# ## Analysis of Year - 2021

# %%
D21.head()
# Out:
#             State/UT   Victims - Below 6 years - Girls  \
# 0     Andhra Pradesh                                24
# 1  Arunachal Pradesh                                 4
# 2              Assam                                33
# 3              Bihar                                 2
# 4       Chhattisgarh                                19
#
#     Victims 6 - 12 years - Girls  Victims 12 - 16 Years - Girls  \
# 0                             78                            390
# 1                              9                             22
# 2                            323                            471
# 3                            106                            301
# 4                             82                            674
#
#    Victims 16 - 18 years - Girls  Total Victims - Girls   \
# 0                            413                     905
# 1                             35                      70
# 2                            493                    1320
# 3                            245                     654
# 4                           1033                    1808
#
#    Victims 18 - 30 years - Women  Victims 30 - 45 years - Women  \
# 0                            463                            108
# 1                             13                              5
# 2                           1306                            470
# 3                            592                            176
# 4                            769                            278
#
#    Victims 45 - 60 years - Women  Victims above 60 years - Women  \
# 0                             14                               5
# 1                             11                               0
# 2                             56                               0
# 3                             18                               0
# 4                             40                               6
#
#    Total Victims - Women  Total Victims
# 0                    590           1495
# 1                     29             99
# 2                   1832           3152
# 3                    786           1440
# 4                   1093           2901

# %%
#lets visualize the above state list

# D21 is the DataFrame with 'State/UT' and 'Total Victims' columns

fig = px.bar(D21, y='State/UT', x='Total Victims', title='Total Victims in State/UT for Year - 2021',
             labels={'Total Victims': 'Total Victims Count', 'State/UT': 'State/UT'})

# Set the figure size
fig.update_layout(width=1000, height=800)

# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="7e068cd3-38f8-461a-9214-8e688bbe2edf" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e068cd3-38f8-461a-9214-8e688bbe2edf")) {                    Plotly.newPlot(                        "7e068cd3-38f8-461a-9214-8e688bbe2edf",                        [{"alignmentgroup":"True","hovertemplate":"Total Victims Count=%{x}<br>State/UT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1495,99,3152,1440,2901,74,2658,2951,360,1994,2652,2370,6469,5986,105,368,91,29,3327,1109,6342,85,3857,2658,154,5594,1127,2708,107,74,50,2092,524,2,2,58],"xaxis":"x","y":["Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","A & N Islands","Chandigarh","D & N Haveli and Daman & Diu","Delhi","Jammu and Kashmir","Ladakh","Lakshadweep","Puducherry"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmo ...

# %% [markdown]
# ### Accessing Population Data

# %%
P21 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population 2021.xlsx")
P21.head(3)
# Out:
#     State/UT                                   Population
# 0   Andhra Pradesh                                    52972000
# 1   Arunachal Pradesh                                  1548000
# 2   Assam                                             35378000

# %%
# Remove any leading or trailing spaces in column names
P21.columns = P21.columns.str.strip()

# Set the display format for float values
pd.options.display.float_format = '{:.0f}'.format

# Assuming 'Population' is the correct column name
P21['Female Population'] = 0.48 * P21['Population']

# Display the resulting dataset
P21.head(3)
# Out:
#                                     State/UT  Population  Female Population
# 0   Andhra Pradesh                              52972000           25426560
# 1   Arunachal Pradesh                            1548000             743040
# 2   Assam                                       35378000           16981440

# %%
#accessing data after merging victims for the two states mentioned above in note

PV21 = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\Population Data\\population vs total victims 2021.xlsx")
PV21.head(3)
# Out:
#                                     State/UT  Female Population  Total Victims
# 0  Andhra Pradesh                                      25426560           1495
# 1  Arunachal Pradesh                                     743040             99
# 2  Assam                                               16981440           3152

# %%
# Create a new column 'Victims per Million'
PV21['Victims per Million'] = (PV21['Total Victims'] / PV21['Female Population']) * 1000000
PV21.head(3)
# Out:
#                                     State/UT  Female Population  \
# 0  Andhra Pradesh                                      25426560
# 1  Arunachal Pradesh                                     743040
# 2  Assam                                               16981440
#
#    Total Victims  Victims per Million
# 0           1495                   59
# 1             99                  133
# 2           3152                  186

# %%
# Create a new dataset with relevant columns
heatmap_data = PV21[['State/UT', 'Victims per Million']]

# Set the 'State/UT' column as the index for the heatmap data
heatmap_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(14, 12))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Cases vs. Population by State - 2021')
plt.show()

# %%
# Sort the dataset based on 'Victims per Million' column in descending order
PV21_sorted = PV21.sort_values(by='Victims per Million', ascending=False)
PV21_sorted.head(3)
# Out:
#                                      State/UT  Female Population  \
# 29                              A & N Islands             192960
# 22  Sikkim                                                327840
# 16  Meghalaya                                            1592640
#
#     Total Victims  Victims per Million
# 29            107                  555
# 22             85                  259
# 16            368                  231

# %%
# Select the top 10 states
top_10_states = PV21_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Victims per Million', y='State/UT', data=top_10_states, palette='viridis')
plt.title('Top 10 States with Highest Victims per Million - 2021')
plt.xlabel('Victims per Million')
plt.ylabel('State/UT')
plt.show()

# %% [markdown]
# ### Most targeted age group - 2021

# %%
# Create a new dataset for percentages
percentage_data = D21.copy()

# Correct column names with spaces
age_groups = [' Victims - Below 6 years - Girls', ' Victims 6 - 12 years - Girls',
              'Victims 12 - 16 Years - Girls', 'Victims 16 - 18 years - Girls',
              'Total Victims - Girls ', 'Victims 18 - 30 years - Women',
              'Victims 30 - 45 years - Women', 'Victims 45 - 60 years - Women',
              'Victims above 60 years - Women', 'Total Victims - Women',
              'Total Victims']

# Check if columns exist before performing operations
for age_group in age_groups:
    if age_group in D21.columns and 'Total Victims' in D21.columns:
        percentage_data[age_group] = ((D21[age_group] / D21['Total Victims']) * 100).round(2)

# Drop unnecessary columns (if needed)
# Note: Adjust the column names based on your dataset
columns_to_drop = ['Total Victims - Girls ', 'Total Victims - Women', 'Total Victims']
percentage_data = percentage_data.drop(columns=columns_to_drop, errors='ignore')

# Display the resulting dataset
percentage_data.head(3)
# Out:
#             State/UT   Victims - Below 6 years - Girls  \
# 0     Andhra Pradesh                                 2
# 1  Arunachal Pradesh                                 4
# 2              Assam                                 1
#
#     Victims 6 - 12 years - Girls  Victims 12 - 16 Years - Girls  \
# 0                              5                             26
# 1                              9                             22
# 2                             10                             15
#
#    Victims 16 - 18 years - Girls  Victims 18 - 30 years - Women  \
# 0                             28                             31
# 1                             35                             13
# 2                             16                             41
#
#    Victims 30 - 45 years - Women  Victims 45 - 60 years - Women  \
# 0                              7                              1
# 1                              5                             11
# 2                             15                              2
#
#    Victims above 60 years - Women
# 0                               0
# 1                               0
# 2                               0

# %%
# Set the state column as the index for better visualization
percentage_data.set_index('State/UT', inplace=True)

# Create a heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(percentage_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=.5)
plt.title('Percentage of Victims by Age Group and State - 2021')
plt.show()

# %% [markdown]
# ## Overall Analysis for all Years

# %%
#data of total victims of India for all years


Total = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\Overall analysis data\\Total victims of each year.xlsx")
Total
# Out:
#    Year  Total Victims
# 0  2016          39068
# 1  2017          51255
# 2  2018          55825
# 3  2019          58489
# 4  2020          56211
# 5  2021          65064

# %%
import plotly.express as px

# Assuming 'Year' is a column in your DataFrame representing the years
# Replace 'Total' with the actual name of your DataFrame if it's different
years = Total['Year']

# Assuming 'Total Victims' is the column you want to plot
total_victims = Total['Total Victims']

# Creating an interactive bar graph with Plotly
fig = px.bar(x=years, y=total_victims, text=total_victims,
             labels={'x': 'Year', 'y': 'Total Victims'},
             title='Total Victims Over the Years (2016-2021)',
             height=500)

# Adjusting the size of the plot
fig.update_layout(width=800)

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="21793118-c8ae-4567-b777-cc4cf5f368a6" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21793118-c8ae-4567-b777-cc4cf5f368a6")) {                    Plotly.newPlot(                        "21793118-c8ae-4567-b777-cc4cf5f368a6",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Total Victims=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[39068.0,51255.0,55825.0,58489.0,56211.0,65064.0],"textposition":"auto","x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[39068,51255,55825,58489,56211,65064],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar ...

# %% [markdown]
# ## Let's explore the Top and Bottom states for various measures

# %% [markdown]
# ## Top 9 States - Total Victims (2016 - 2021)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Datasets are named D16, D17, D18, D19, D20, D21
datasets = [D16, D17, D18, D19, D20, D21]
states_to_compare = ['Madhya Pradesh', 'Rajasthan', 'Uttar Pradesh', 'Chhattisgarh', 'Maharashtra', 'Assam', 'Odisha', 'Delhi', 'West Bengal']

# Create an empty DataFrame to store the count of total victims for each state and year
comparison_data = pd.DataFrame(columns=['Year', 'State/UT', 'Total Victims'])

# Loop through each dataset and extract the count for the specified states
for year, dataset in zip(range(2016, 2022), datasets):
    total_victims_by_state = dataset.groupby('State/UT')['Total Victims'].sum().reset_index()
    total_victims_by_state = total_victims_by_state[total_victims_by_state['State/UT'].isin(states_to_compare)]
    
    # Add the year column
    total_victims_by_state['Year'] = year
    
    # Append the data to the comparison DataFrame
    comparison_data = pd.concat([comparison_data, total_victims_by_state], ignore_index=True)

# Create traces for each state
traces = []
for state in states_to_compare:
    trace = go.Scatter(
        x=comparison_data[comparison_data['State/UT'] == state]['Year'],
        y=comparison_data[comparison_data['State/UT'] == state]['Total Victims'],
        mode='lines',
        name=state
    )
    traces.append(trace)

# Create a subplot with a dropdown menu
fig = make_subplots(rows=1, cols=1, specs=[[{'type': 'scatter'}]])
dropdown_buttons = [
    {
        'method': 'update',
        'label': 'Show All',
        'args': [{'visible': [True] * len(traces)}]
    }
] + [
    {
        'method': 'update',
        'label': state,
        'args': [{'visible': [state == trace.name for trace in traces]}]
    }
    for state in states_to_compare
]
fig.update_layout(
    updatemenus=[{
        'active': 0,
        'buttons': dropdown_buttons,
        'showactive': True,
    }],
    height=600, width=1000,
    title='Comparison of Total Victims for Selected States (2016-2021)',
    xaxis_title='Year',
    yaxis_title='Total Victims'
)

# Add traces to the subplot
for trace in traces:
    fig.add_trace(trace)

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="00aa60a3-61d6-407e-a2b4-397b704ebb69" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00aa60a3-61d6-407e-a2b4-397b704ebb69")) {                    Plotly.newPlot(                        "00aa60a3-61d6-407e-a2b4-397b704ebb69",                        [{"mode":"lines","name":"Madhya Pradesh","x":[2016,2017,2018,2019,2020,2021],"y":[4908,6549,6498,5839,5603,6469],"type":"scatter"},{"mode":"lines","name":"Rajasthan","x":[2016,2017,2018,2019,2020,2021],"y":[3657,3939,4412,6053,5338,6342],"type":"scatter"},{"mode":"lines","name":"Uttar Pradesh","x":[2016,2017,2018,2019,2020,2021],"y":[4817,6261,6447,6432,5329,5594],"type":"scatter"},{"mode":"lines","name":"Chhattisgarh","x":[2016,2017,2018,2019,2020,2021],"y":[1627,3029,3323,2427,2753,2901],"type":"scatter"},{"mode":"lines","name":"Maharashtra","x":[2016,2017,2018,2019,2020,2021],"y":[4216,4341,5093,5466,4865,5986],"type":"scatter"},{"mode":"lines","name":"Assam","x":[2016,2017,2018,2019,2020,2021],"y":[1779,2846,3000,3081,2736,3152],"type":"scatter"},{"mode":"lines","name":"Odisha","x":[2016,2017,2018,2019,2020,2021],"y":[1984,2232,2354,2888,2840,3327],"type":"scatter"},{"mode":"lines","name":"Delhi","x":[2016,2017,2018,2019,2020,2021],"y":[2170,2172,2206,2210,1718,2092],"type":"scatter"},{"mode":"lines","name":"West Bengal","x":[2016,2017,2018,2019,2020,2021],"y":[1110,2294,2438,2438,2714,2708],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66 ...

# %% [markdown]
# ### Count of Total Victims for all 6 Years

# %%
# Datasets are named D16, D17, D18, D19, D20, D21
datasets = [D16, D17, D18, D19, D20, D21]
states_to_compare = ['Madhya Pradesh', 'Rajasthan', 'Uttar Pradesh', 'Chhattisgarh', 'Maharashtra', 'Assam', 'Odisha', 'Delhi', 'West Bengal']

# Create an empty DataFrame to store the total count of victims for each state
total_victims_data = pd.DataFrame(columns=['State/UT', 'Total Victims', 'Year'])

# Loop through each dataset and extract the count for the specified states
for i, dataset in enumerate(datasets):
    total_victims_by_state = dataset.groupby('State/UT')['Total Victims'].sum().reset_index()
    total_victims_by_state = total_victims_by_state[total_victims_by_state['State/UT'].isin(states_to_compare)]
    
    # Add the year information to the DataFrame
    total_victims_by_state['Year'] = f'20{i + 16}'
    
    # Append the data to the total victims DataFrame
    total_victims_data = pd.concat([total_victims_data, total_victims_by_state], ignore_index=True)

# Create a bar chart for total victims across all years
fig = px.bar(total_victims_data, x='State/UT', y='Total Victims', color='Year',
             labels={'Total Victims': 'Total Victims'},
             title='Total Victims of 6 years for the top 9 states',
             height=600, width=1200,
             hover_data={'Year': True, 'Total Victims': ':.0f'})  # Specify the hover_data

# Customize the layout as needed
fig.update_layout(xaxis_title='State/UT', yaxis_title='Total Victims')

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="c6efe958-534e-4f89-882d-936bc6f72829" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6efe958-534e-4f89-882d-936bc6f72829")) {                    Plotly.newPlot(                        "c6efe958-534e-4f89-882d-936bc6f72829",                        [{"alignmentgroup":"True","customdata":[["2016"],["2016"],["2016"],["2016"],["2016"],["2016"],["2016"],["2016"],["2016"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2016","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2016","offsetgroup":"2016","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam","Chhattisgarh","Delhi","Madhya Pradesh","Maharashtra","Odisha","Rajasthan","Uttar Pradesh","West Bengal"],"xaxis":"x","y":[1779,1627,2170,4908,4216,1984,3657,4817,1110],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017"],["2017"],["2017"],["2017"],["2017"],["2017"],["2017"],["2017"],["2017"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2017","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2017","offsetgroup":"2017","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam","Chhattisgarh","Delhi","Madhya Pradesh","Maharashtra","Odisha","Rajasthan","Uttar Pradesh","West Bengal"],"xaxis":"x","y":[2846,3029,2172,6549,4341,2232,3939,6261,2294],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018"],["2018"],["2018"],["2018"],["2018"],["2018"],["2018"],["2018"],["2018"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2018","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"2018","offsetgroup":"2018","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam","Chhattisgarh","Delhi","Madhya Pradesh","Maharashtra","Odisha","Rajasthan","Uttar Pradesh","West Bengal"],"xaxis":"x","y":[3000,3323,2206,6498,5093,2354,4412,6447,2438],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019"],["2019"],["2019"],["2019"],["2019"],["2019"],["2019"],["2019"],["2019"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2019","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam","Chhattisgarh","Delhi","Madhya Pradesh","Maharashtra","Odisha","Rajasthan","Uttar Pradesh","West Bengal"],"xaxis":"x","y":[3081,2427,2210,5839,5466,2888,6053,6432,2438],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2020"],["2020"],["2020"],["2020"],["2020"],["2020"],["2020"],["2020"],["2020"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2020","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"2020","offsetgroup":"2020","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam","Chhattisgarh","Delhi","Madhya Pradesh","Maharashtra","Odisha","Rajasthan","Uttar Pradesh","West Bengal"],"xaxis":"x","y":[2736,2753,1718,5603,4865,2840,5338,5329,2714],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2021"],["2021"],["2021"],["2021"],["2021"],["2021"],["2021"],["2021"],["2021"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2021","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"2021","offsetgroup":"2021","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam","Chhattisgarh","Delhi","Madhya Pradesh","Maharashtra","Odisha","Rajasthan","Uttar Pradesh","West Bengal" ...

# %% [markdown]
# ### Extracting the datasets from 2016 to 2019 , where D&N Haveli and Daman & Diu has been added, so that we can explore the lowest count states

# %%
# Read the datasets

D16c = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\DAMAN combined data\\Victims of Rape - 2016 - Copy.xlsx")
D17c = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\DAMAN combined data\\Victims of Rape - 2017 - Copy.xlsx")
D18c = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\DAMAN combined data\\Victims of Rapes - 2018 - Copy.xlsx")
D19c = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\VICTIMS OF RAPE - GIRLS AND WOMEN\\DAMAN combined data\\Victims of Rape - 2019 - Copy.xlsx")

# %% [markdown]
# ### 10 States with lowest count

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# datasets are named D16c, D17c, D18c, D19c, D20, D21
datasets = [D16c, D17c, D18c, D19c, D20, D21]

# List of states to compare (lowest 10)
states_to_compare_lowest = [
    'Lakshadweep',
    'D & N Haveli and Daman & Diu',
    'Nagaland',
    'Puducherry',
    'Manipur',
    'A & N Islands',
    'Chandigarh',
    'Goa',
    'Arunachal Pradesh',
    'Sikkim'
]

# Create an empty DataFrame to store the count of total victims for each state and year
comparison_data_lowest = pd.DataFrame(columns=['Year', 'State/UT', 'Total Victims'])

# Loop through each dataset and extract the count for the specified states
for year, dataset in zip(range(2016, 2022), datasets):
    total_victims_by_state_lowest = dataset.groupby('State/UT')['Total Victims'].sum().reset_index()
    total_victims_by_state_lowest = total_victims_by_state_lowest[total_victims_by_state_lowest['State/UT'].isin(states_to_compare_lowest)]
    
    # Add the year column
    total_victims_by_state_lowest['Year'] = year
    
    # Append the data to the comparison DataFrame
    comparison_data_lowest = pd.concat([comparison_data_lowest, total_victims_by_state_lowest], ignore_index=True)

# Create traces for each state (lowest 10)
traces_lowest = []
for state_lowest in states_to_compare_lowest:
    trace_lowest = go.Scatter(
        x=comparison_data_lowest[comparison_data_lowest['State/UT'] == state_lowest]['Year'],
        y=comparison_data_lowest[comparison_data_lowest['State/UT'] == state_lowest]['Total Victims'],
        mode='lines',
        name=state_lowest
    )
    traces_lowest.append(trace_lowest)

# Create a subplot with a dropdown menu
fig_lowest = make_subplots(rows=1, cols=1, specs=[[{'type': 'scatter'}]])
dropdown_buttons_lowest = [
    {
        'method': 'update',
        'label': 'Show All',
        'args': [{'visible': [True] * len(traces_lowest)}]
    }
] + [
    {
        'method': 'update',
        'label': state_lowest,
        'args': [{'visible': [state_lowest == trace_lowest.name for trace_lowest in traces_lowest]}]
    }
    for state_lowest in states_to_compare_lowest
]
fig_lowest.update_layout(
    updatemenus=[{
        'active': 0,
        'buttons': dropdown_buttons_lowest,
        'showactive': True,
    }],
    height=600, width=1000,
    title='Comparison of Total Victims for Lowest 10 States (2016-2021)',
    xaxis_title='Year',
    yaxis_title='Total Victims'
)

# Add traces to the subplot
for trace_lowest in traces_lowest:
    fig_lowest.add_trace(trace_lowest)

# Show the interactive plot
fig_lowest.show()
# Out:
# <div>                            <div id="86e7e254-aa7e-4ca6-8bb5-c37bdea068cc" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86e7e254-aa7e-4ca6-8bb5-c37bdea068cc")) {                    Plotly.newPlot(                        "86e7e254-aa7e-4ca6-8bb5-c37bdea068cc",                        [{"mode":"lines","name":"Lakshadweep","x":[2016,2017,2018,2019,2020,2021],"y":[5,3,3,14,6,2],"type":"scatter"},{"mode":"lines","name":"D & N Haveli and Daman & Diu","x":[2016,2017,2018,2019,2020,2021],"y":[26,17,28,51,43,50],"type":"scatter"},{"mode":"lines","name":"Nagaland","x":[2016,2017,2018,2019,2020,2021],"y":[26,38,19,20,18,29],"type":"scatter"},{"mode":"lines","name":"Puducherry","x":[2016,2017,2018,2019,2020,2021],"y":[6,48,47,58,52,58],"type":"scatter"},{"mode":"lines","name":"Manipur","x":[2016,2017,2018,2019,2020,2021],"y":[55,55,85,83,88,105],"type":"scatter"},{"mode":"lines","name":"A & N Islands","x":[2016,2017,2018,2019,2020,2021],"y":[30,60,81,96,106,107],"type":"scatter"},{"mode":"lines","name":"Chandigarh","x":[2016,2017,2018,2019,2020,2021],"y":[69,65,86,113,60,74],"type":"scatter"},{"mode":"lines","name":"Goa","x":[2016,2017,2018,2019,2020,2021],"y":[61,76,61,74,61,74],"type":"scatter"},{"mode":"lines","name":"Arunachal Pradesh","x":[2016,2017,2018,2019,2020,2021],"y":[92,82,88,88,79,99],"type":"scatter"},{"mode":"lines","name":"Sikkim","x":[2016,2017,2018,2019,2020,2021],"y":[98,86,95,69,85,85],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...

# %%
# datasets are named D16c, D17c, D18c, D19c, D20, D21
datasets_lowest = [D16c, D17c, D18c, D19c, D20, D21]
states_to_compare_lowest = ['Lakshadweep', 'D & N Haveli and Daman & Diu', 'Nagaland', 'Puducherry', 'Manipur', 'A & N Islands', 'Chandigarh', 'Goa', 'Arunachal Pradesh', 'Sikkim']

# Create an empty DataFrame to store the total count of victims for each state
total_victims_data_lowest = pd.DataFrame(columns=['State/UT', 'Total Victims', 'Year'])

# Loop through each dataset and extract the count for the specified states
for i, dataset in enumerate(datasets):
    total_victims_by_state_lowest = dataset.groupby('State/UT')['Total Victims'].sum().reset_index()
    total_victims_by_state_lowest = total_victims_by_state_lowest[total_victims_by_state_lowest['State/UT'].isin(states_to_compare_lowest)]
    
    # Add the year information to the DataFrame
    total_victims_by_state_lowest['Year'] = f'20{i + 16}'
    
    # Sort by total victims in ascending order and select the bottom 10
    total_victims_by_state_lowest = total_victims_by_state_lowest.sort_values(by='Total Victims').head(10)
    
    # Append the data to the total victims DataFrame
    total_victims_data_lowest = pd.concat([total_victims_data_lowest, total_victims_by_state_lowest], ignore_index=True)

# Create a bar chart for total victims across all years for the lowest 10 states
fig_lowest = px.bar(total_victims_data_lowest, x='State/UT', y='Total Victims', color='Year',
                    labels={'Total Victims': 'Total Victims'},
                    title='Total Victims of 6 years for the lowest 10 states ',
                    height=600, width=1200,
                    hover_data={'Year': True, 'Total Victims': ':.0f'})  # Specify the hover_data

# Customize the layout as needed
fig_lowest.update_layout(xaxis_title='State/UT', yaxis_title='Total Victims')

# Show the interactive plot
fig_lowest.show()
# Out:
# <div>                            <div id="810a8f23-a0b9-4576-bb31-92a3bc6efccb" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("810a8f23-a0b9-4576-bb31-92a3bc6efccb")) {                    Plotly.newPlot(                        "810a8f23-a0b9-4576-bb31-92a3bc6efccb",                        [{"alignmentgroup":"True","customdata":[["2016"],["2016"],["2016"],["2016"],["2016"],["2016"],["2016"],["2016"],["2016"],["2016"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2016","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2016","offsetgroup":"2016","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshadweep","Puducherry","D & N Haveli and Daman & Diu","Nagaland","A & N Islands","Manipur","Goa","Chandigarh","Arunachal Pradesh","Sikkim"],"xaxis":"x","y":[5,6,26,26,30,55,61,69,92,98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017"],["2017"],["2017"],["2017"],["2017"],["2017"],["2017"],["2017"],["2017"],["2017"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2017","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2017","offsetgroup":"2017","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshadweep","D & N Haveli and Daman & Diu","Nagaland","Puducherry","Manipur","A & N Islands","Chandigarh","Goa","Arunachal Pradesh","Sikkim"],"xaxis":"x","y":[3,17,38,48,55,60,65,76,82,86],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018"],["2018"],["2018"],["2018"],["2018"],["2018"],["2018"],["2018"],["2018"],["2018"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2018","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"2018","offsetgroup":"2018","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshadweep","Nagaland","D & N Haveli and Daman & Diu","Puducherry","Goa","A & N Islands","Manipur","Chandigarh","Arunachal Pradesh","Sikkim"],"xaxis":"x","y":[3,19,28,47,61,81,85,86,88,95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019"],["2019"],["2019"],["2019"],["2019"],["2019"],["2019"],["2019"],["2019"],["2019"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2019","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshadweep","Nagaland","D & N Haveli and Daman & Diu","Puducherry","Sikkim","Goa","Manipur","Arunachal Pradesh","A & N Islands","Chandigarh"],"xaxis":"x","y":[14,20,51,58,69,74,83,88,96,113],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2020"],["2020"],["2020"],["2020"],["2020"],["2020"],["2020"],["2020"],["2020"],["2020"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2020","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"2020","offsetgroup":"2020","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshadweep","Nagaland","D & N Haveli and Daman & Diu","Puducherry","Chandigarh","Goa","Arunachal Pradesh","Sikkim","Manipur","A & N Islands"],"xaxis":"x","y":[6,18,43,52,60,61,79,85,88,106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2021"],["2021"],["2021"],["2021"],["2021"],["2021"],["2021"],["2021"],["2021"],["2021"]],"hovertemplate":"Year=%{customdata[0]}<br>State/UT=%{x}<br>Total Victims=%{y:.0f}<extra></extra>","legendgroup":"2021","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"2021","offsetgroup":"2021","orientation":"v","showlegend":true,"textposition ...

# %% [markdown]
# ### I created a seperate dataset of Rate of Rape - All years for Top states

# %%
# Define the data
data = {
    'State/UT': ['A & N Islands', 'Mizoram', 'Sikkim', 'Delhi', 'Chhattisgarh', 'Meghalaya', 'Assam', 'Madhya Pradesh', 'Kerala', 'Haryana'],
    '2017': [301.89, 271.59, 270.54, 249.86, 224.37, 184.46, 174.04, 168.66, 133.58, 130.88],
    '2018': [401.81, 294.64, 250.51, 242.34, 210.76, 180.71, 176.25, 169.78, 164.40, 162.68],
    '2019': [486.29, 404.12, 248.90, 211.17, 206.06, 194.82, 182.97, 174.98, 174.41, 158.45],
    '2020': [529.53, 256.55, 196.78, 194.84, 191.29, 177.79, 170.80, 163.51, 160.08, 152.98],
    '2021': [554.52, 259.27, 231.06, 207.89, 205.99, 203.85, 202.57, 185.61, 164.84, 161.71]
}

# Create a DataFrame
rape_rate_table = pd.DataFrame(data)

# Display the table
rape_rate_table
# Out:
#          State/UT  2017  2018  2019  2020  2021
# 0   A & N Islands   302   402   486   530   555
# 1         Mizoram   272   295   404   257   259
# 2          Sikkim   271   251   249   197   231
# 3           Delhi   250   242   211   195   208
# 4    Chhattisgarh   224   211   206   191   206
# 5       Meghalaya   184   181   195   178   204
# 6           Assam   174   176   183   171   203
# 7  Madhya Pradesh   169   170   175   164   186
# 8          Kerala   134   164   174   160   165
# 9         Haryana   131   163   158   153   162

# %%
# Set the State/UT column as the index
rape_rate_table.set_index('State/UT', inplace=True)

# Plot the data
plt.figure(figsize=(12, 6))
for state in rape_rate_table.index:
    plt.plot(rape_rate_table.columns, rape_rate_table.loc[state], label=state, marker='o')

plt.title('Rape Rates Over the Years (2017-2021)')
plt.xlabel('Year')
plt.ylabel('Rape Rate Per Million')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.show()

# %% [markdown]
# ## Let's explore what is the Rural and Urban distribution in India, to find if we can find any relation between them.
#
# ### The analysis is explained in report

# %%
# accessing data extracted from NCRB

R_U_c = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\rural and urban - Copy.xlsx")

R_U_c.head()
# Out:
#               State  Rural Percent  Urban Percent
# 0   Jammu & Kashmir             73             27
# 1  Himachal Pradesh             90             10
# 2            Punjab             63             37
# 3        Chandigarh              3             97
# 4       Uttarakhand             70             30

# %%
# Plotting
plt.figure(figsize=(12, 9))
plt.barh(R_U_c['State'], R_U_c['Rural Percent'], label='Rural', color='lightblue')
plt.barh(R_U_c['State'], R_U_c['Urban Percent'], left=R_U_c['Rural Percent'], label='Urban', color='orange')

plt.xlabel('Percentage')
plt.title('Rural and Urban Percentages for Each State')
plt.legend()
plt.show()

# %% [markdown]
# ## Let's explore and do some analysis on 5 states which have higher count and rate trend in all years - 'Madhya Pradesh', 'Uttar Pradesh', 'Rajasthan', 'Delhi', 'Maharashtra'

# %% [markdown]
# ### I separately stored these 5 states data in a separate file for easy analysis

# %%
#accessing the dataset

States_to_compare = pd.read_excel("C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\states to compare\\states.xlsx")
States_to_compare
# Out:
#          State/UT  Total Girls  Total Women  Total Victims
# 0  Madhya Pradesh         2479         2429           4908
# 1     Maharashtra         2310         1906           4216
# 2       Rajasthan          777         2880           3657
# 3   Uttar Pradesh         2115         2702           4817
# 4           Delhi          800         1370           2170

# %% [markdown]
# ### Total Victims in all years for these 5 states

# %%
#accessing data

file_path = "C:\\Users\\aiman\\OneDrive\\Desktop\\Rapes in India\\states to compare\\states.xlsx"

# Create an empty DataFrame to store all data
all_data = pd.DataFrame()

# Read data from each sheet and append it to the DataFrame
for year in range(2016, 2022):
    sheet_name = str(year)
    data = pd.read_excel(file_path, sheet_name=sheet_name)
    data['Year'] = year  # Add a column for the year
    all_data = all_data.append(data)

# Create line plots for each column
fig_girls = px.line(all_data, x='Year', y='Total Girls', color='State/UT',
                    labels={'Total Girls': 'Count'}, title='Trends in Total Girls Over the Years',
                    line_shape='linear', render_mode='svg')

fig_women = px.line(all_data, x='Year', y='Total Women', color='State/UT',
                    labels={'Total Women': 'Count'}, title='Trends in Total Women Over the Years',
                    line_shape='linear', render_mode='svg')

fig_victims = px.line(all_data, x='Year', y='Total Victims', color='State/UT',
                      labels={'Total Victims': 'Count'}, title='Trends in Total Victims Over the Years',
                      line_shape='linear', render_mode='svg')

# Show the interactive plots
fig_girls.show()
fig_women.show()
fig_victims.show()
# Out:
# C:\Users\aiman\AppData\Local\Temp\ipykernel_3840\2534298078.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\aiman\AppData\Local\Temp\ipykernel_3840\2534298078.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\aiman\AppData\Local\Temp\ipykernel_3840\2534298078.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\aiman\AppData\Local\Temp\ipykernel_3840\2534298078.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\aiman\AppData\Local\Temp\ipykernel_3840\2534298078.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\aiman\AppData\Local\Temp\ipykernel_3840\2534298078.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <div>                            <div id="fe4c1a8d-a08f-4448-a425-54f0f24bf5fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe4c1a8d-a08f-4448-a425-54f0f24bf5fb")) {                    Plotly.newPlot(                        "fe4c1a8d-a08f-4448-a425-54f0f24bf5fb",                        [{"hovertemplate":"State/UT=Madhya Pradesh<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Madhya Pradesh","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Madhya Pradesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2479,4032,3272,3522,3889,3349],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Maharashtra<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Maharashtra","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Maharashtra","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2310,2408,2800,3508,2944,3161],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Rajasthan<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Rajasthan","line":{"color":"#00cc96","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Rajasthan","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[777,1132,1280,1453,1107,1316],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Uttar Pradesh<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Uttar Pradesh","line":{"color":"#ab63fa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Uttar Pradesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2115,3152,2739,3005,3536,3573],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Delhi<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Delhi","line":{"color":"#FFA15A","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Delhi","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[800,941,721,841,989,957],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...
# <div>                            <div id="acf61340-023d-4f7d-a4e5-ada9c1b181d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acf61340-023d-4f7d-a4e5-ada9c1b181d7")) {                    Plotly.newPlot(                        "acf61340-023d-4f7d-a4e5-ada9c1b181d7",                        [{"hovertemplate":"State/UT=Madhya Pradesh<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Madhya Pradesh","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Madhya Pradesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2429,2517,2331,2947,2609,2490],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Maharashtra<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Maharashtra","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Maharashtra","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1906,1933,2065,2478,2149,2305],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Rajasthan<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Rajasthan","line":{"color":"#00cc96","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Rajasthan","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2880,2807,4058,4889,3305,4737],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Uttar Pradesh<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Uttar Pradesh","line":{"color":"#ab63fa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Uttar Pradesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2702,3109,2590,2589,2911,2859],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Delhi<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Delhi","line":{"color":"#FFA15A","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Delhi","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1370,1231,997,1251,1217,1253],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...
# <div>                            <div id="ff10aa4d-b143-4814-ab76-2886e7d21360" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff10aa4d-b143-4814-ab76-2886e7d21360")) {                    Plotly.newPlot(                        "ff10aa4d-b143-4814-ab76-2886e7d21360",                        [{"hovertemplate":"State/UT=Madhya Pradesh<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Madhya Pradesh","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Madhya Pradesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4908,6549,5603,6469,6498,5839],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Maharashtra<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Maharashtra","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Maharashtra","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4216,4341,4865,5986,5093,5466],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Rajasthan<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Rajasthan","line":{"color":"#00cc96","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Rajasthan","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[3657,3939,5338,6342,4412,6053],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Uttar Pradesh<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Uttar Pradesh","line":{"color":"#ab63fa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Uttar Pradesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4817,6261,5329,5594,6447,6432],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=Delhi<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Delhi","line":{"color":"#FFA15A","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Delhi","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2170,2172,1718,2092,2206,2210],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777 ...

# %% [markdown]
# ### Comparison between Rural and Urban distribution

# %%
# Filtering data for specific states
selected_states = ['Madhya Pradesh', 'Uttar Pradesh', 'Rajasthan', 'Delhi', 'Maharashtra']
selected_data = R_U[R_U['State'].isin(selected_states)]

# Plotting the 'Rural Percent' and 'Urban Percent' columns for the selected states
fig, ax = plt.subplots(figsize=(10, 6))
selected_data.plot(kind='bar', x='State', y=['Rural Percent', 'Urban Percent'], ax=ax)
ax.set_ylabel('Percentage')
ax.set_title('Rural and Urban Percentage for Selected States - 2016 - 2021')
ax.legend(title='Population', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filtering data for specific states
selected_states = ['Madhya Pradesh', 'Uttar Pradesh', 'Rajasthan', 'Delhi', 'Maharashtra']
selected_data = R_U[R_U['State'].isin(selected_states)]

# Creating a bar plot using Plotly with percentage values on the bars
fig = px.bar(selected_data, x='State', y=['Rural Percent', 'Urban Percent'],
             title='Rural and Urban Percentage for Selected States',
             labels={'value': 'Percentage', 'variable': 'Population'},
             color_discrete_map={'Rural Percent': 'blue', 'Urban Percent': 'orange'})

# Adding text annotations for percentage values on the bars
for trace in fig.data:
    trace.text = ['{}%'.format(round(val, 2)) for val in trace.y]

# Rotating x-axis labels for better visibility
fig.update_xaxes(tickangle=45, tickmode='array')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="b035a30d-d9ff-40c1-a3e6-41d63c6c755e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b035a30d-d9ff-40c1-a3e6-41d63c6c755e")) {                    Plotly.newPlot(                        "b035a30d-d9ff-40c1-a3e6-41d63c6c755e",                        [{"alignmentgroup":"True","hovertemplate":"Population=Rural Percent<br>State=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Rural Percent","marker":{"color":"blue","pattern":{"shape":""}},"name":"Rural Percent","offsetgroup":"Rural Percent","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi","Rajasthan","Uttar Pradesh","Madhya Pradesh","Maharashtra"],"xaxis":"x","y":[2.5,75.11,77.7,72.36,54.74],"yaxis":"y","type":"bar","text":["2.5%","75.11%","77.7%","72.36%","54.74%"]},{"alignmentgroup":"True","hovertemplate":"Population=Urban Percent<br>State=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Urban Percent","marker":{"color":"orange","pattern":{"shape":""}},"name":"Urban Percent","offsetgroup":"Urban Percent","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi","Rajasthan","Uttar Pradesh","Madhya Pradesh","Maharashtra"],"xaxis":"x","y":[97.5,24.89,22.3,27.64,45.26],"yaxis":"y","type":"bar","text":["97.5%","24.89%","22.3%","27.64%","45.26%"]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":" ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, the comprehensive analysis of rape cases in India underscores the multifaceted nature of this pervasive issue. The study delved into national and state-level data, comparing high and low victim count states, exploring age group vulnerabilities, and assessing the rate of reported cases per million.
#
# The findings revealed stark variations across states, emphasizing the need for targeted interventions considering regional dynamics. Madhya Pradesh, Maharashtra, Rajasthan, and Uttar Pradesh emerged as states with significant challenges, demanding focused attention and tailored strategies.
#
# Understanding age group vulnerabilities showcased the importance of addressing the unique needs of victims across different life stages. The analysis of rates per million highlighted the disparities in reporting mechanisms and the urgent need for a more consistent and victim-centric approach nationwide.
#
# Despite the gravity of the situation, it is crucial to acknowledge the limitations of reported data, as dark data remains a significant concern. Factors contributing to underreporting, including societal norms, legal barriers, and fear, necessitate a holistic approach for improvement.
#
# Future work should explore diverse data sources, leverage technology, and engage in community empowerment programs to dismantle stigmas and encourage reporting. Legal reforms, international collaboration, and sustained public awareness campaigns are pivotal components of a comprehensive strategy to address this pervasive issue.
#
# In moving forward, continuous evaluation of initiatives, integration of crisis intervention, and counselling services into the reporting process will contribute to a more responsive and supportive system. By prioritizing victim protections, fostering public trust in law enforcement, and dismantling barriers to reporting, India can strive towards a safer and more inclusive society. The analysis serves as a foundation for informed policy decisions, encouraging collaborative efforts to combat sexual violence and champion the rights and well-being of survivors.
